# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %tensorflow_version 2.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name == '/device:GPU:0':
  print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow import keras as keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Conv2D, Conv2DTranspose, MaxPooling2D, UpSampling2D, Cropping2D
from tensorflow.keras.layers import Dense, Activation, Flatten, BatchNormalization
from tensorflow.keras.layers import Input, Lambda,  Reshape
from tensorflow.keras.losses import mse
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import Model, load_model

# %%
from tensorflow.python.framework.ops import disable_eager_execution
disable_eager_execution()
tf.__version__
# Out:
# '2.6.0'

# %%
tf.keras.backend.set_floatx('float32')

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)

# %%
# Move data from GDrive to VM, it will speed up the data read process
# !cp -r /content/drive/MyDrive/UpWork/ChepVAE/10230/hdf5 .
# !ls -l
# Out:
# total 52
# drwx------ 5 root root  4096 Sep 25 13:41 drive
# drwx------ 2 root root 40960 Sep 25 13:57 hdf5
# drwxr-xr-x 1 root root  4096 Sep 16 13:40 sample_data

# %%
import os
import json
import h5py
import numpy as np
import pandas as pd
from datetime import datetime
from tqdm import tqdm
import matplotlib.pyplot as plt
import sys
sys.path.append('/content/drive/MyDrive/UpWork/ChepVAE/src')
from custom_data_gen import CustomDataGenerator

# %%
config = {}
config['latentDim'] = 64
config['batchSize'] = 32
config['numEpochs'] = 5
config['height'] = 270
config['width'] = 270
config['saveDir'] = '/content/drive/MyDrive/UpWork/ChepVAE/10230/model_2/'

original_dim = config['height'] * config['width']
data_split_path = '/content/drive/MyDrive/UpWork/ChepVAE/10230/datasplit.csv'
data_path = '/content/drive/MyDrive/UpWork/ChepVAE/10230/hdf5/'
data_path = 'hdf5/'
os.makedirs(config['saveDir'], exist_ok=True)

# %%
cdg_train = CustomDataGenerator(datasplit_path=data_split_path, data_path=data_path, split='Train', batch_size=config['batchSize'], rotate=True)
cdg_val = CustomDataGenerator(datasplit_path=data_split_path, data_path=data_path, split='Val', shuffle=False, batch_size=config['batchSize'], rotate=True)
print("Length of train data: ", len(cdg_train))
print("Length of val data: ", len(cdg_val))
# Out:
# Length of train data:  3025
# Length of val data:  709

# %%
class Sampling(layers.Layer):
  """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

  def call(self, inputs):
    z_mean, z_log_var = inputs
    batch = tf.shape(z_mean)[0]
    dim = tf.shape(z_mean)[1]
    epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
    return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %%
input_img = Input(shape=(config['height'], config['width'], 1), name='eninput')

x = Conv2D(16, (3, 3), padding='same', name='enconv1')(input_img)
x = BatchNormalization(name='enbatch1')(x)
x = Activation('relu', name='enrelu1')(x)
x = MaxPooling2D((2, 2), padding='same', name='enpool1')(x)

x = Conv2D(32, (3, 3), padding='same', name='enconv2')(x)
x = BatchNormalization(name='enbatch2')(x)
x = Activation('relu', name='enrelu2')(x)
x = MaxPooling2D((2, 2), padding='same', name='enpool2')(x)

x = Conv2D(64, (3, 3), padding='same', name='enconv3')(x)
x = BatchNormalization(name='enbatch3')(x)
x = Activation('relu', name='enrelu3')(x)
x = MaxPooling2D((2, 2), padding='same', name='enpool3')(x)

x = Conv2D(64, (3, 3), padding='same', name='enconv4')(x)
x = BatchNormalization(name='enbatch4')(x)
x = Activation('relu', name='enrelu4')(x)
x = MaxPooling2D((2, 2), padding='same', name='enpool4')(x)

x = Conv2D(32, (3, 3), padding='same', name='enconv5')(x)
x = BatchNormalization(name='enbatch5')(x)
x = Activation('relu', name='enrelu5')(x)
x = MaxPooling2D((2, 2), padding='same', name='enpool5')(x)


shape_before_flattening = K.int_shape(x)
x = Flatten(name='enflat')(x)
x = Dense(config['latentDim'], activation='relu', name='endense')(x)

# Two outputs, latent mean and (log) variance
z_mean = Dense(config['latentDim'], name='enzmean')(x)
z_log_var = Dense(config['latentDim'], name='enzlogsigma')(x)
z = Sampling()([z_mean, z_log_var])
encoder = Model(input_img, [z_mean, z_log_var, z], name='encoder')

# %%
# encoder.summary()

# %%
latent_inputs = Input(shape=(config['latentDim'], ), name='deinput')
x = Dense(config['latentDim'], activation='relu', name='dedense1')(latent_inputs)
x = Dense(np.prod(shape_before_flattening[1:]), activation='relu', name='dedense2')(x)
x = Reshape(shape_before_flattening[1:], name='dereshape')(x)

x = Conv2DTranspose(32, (3, 3), padding='same', name='deconv2')(x)
x = BatchNormalization(name='debatch2')(x)
x = Activation('relu', name='derelu2')(x)
x = UpSampling2D((2, 2), name='deup2')(x)

x = Conv2DTranspose(64, (3, 3), padding='same', name='deconv3')(x)
x = BatchNormalization(name='debatch3')(x)
x = Activation('relu', name='derelu3')(x)
x = UpSampling2D((2, 2), name='deup3')(x)

x = Conv2DTranspose(64, (3, 3), padding='same', name='deconv4')(x)
x = BatchNormalization(name='debatch4')(x)
x = Activation('relu', name='derelu4')(x)
x = UpSampling2D((2, 2), name='deup4')(x)

x = Conv2DTranspose(32, (3, 3), padding='same', name='deconv5')(x)
x = BatchNormalization(name='debatch5')(x)
x = Activation('relu', name='derelu5')(x)
x = UpSampling2D((2, 2), name='deup5')(x)

x = Conv2DTranspose(16, (3, 3), padding='same', name='deconv6')(x)
x = BatchNormalization(name='debatch6')(x)
x = Activation('relu', name='derelu6')(x)
x = UpSampling2D((2, 2), name='deup6')(x)

x = Conv2DTranspose(1, (3, 3), padding='same', name='deconv7')(x)
x = BatchNormalization(name='debatch7')(x)
x = Activation('linear', name='derelu7')(x)
decoded = Cropping2D(cropping=((9, 9), (9, 9)), data_format=None, name='decrop7')(x)

decoder = Model(latent_inputs, decoded, name='decoder')

# %%
# decoder.summary()

# %%
def vae_loss(y_true, y_pred):
  reconstruction_loss = mse(K.flatten(y_true), K.flatten(y_pred))
  reconstruction_loss *= original_dim
  kl_loss = 1 + z_log_var - K.square(z_mean) - K.exp(z_log_var)
  kl_loss = K.sum(kl_loss, axis=-1)
  kl_loss *= -0.5
  vae_loss = K.mean(reconstruction_loss + kl_loss)
  return vae_loss

# %%
with tf.device('/device:GPU:0'):
  outputs = decoder(encoder(input_img)[2])
  vae = Model(input_img, outputs, name='vae_mlp')

# %%
vae.summary()
# Out:
# Model: "vae_mlp"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# eninput (InputLayer)         [(None, 270, 270, 1)]     0
# _________________________________________________________________
# encoder (Functional)         [(None, 64), (None, 64),  253792
# _________________________________________________________________
# decoder (Functional)         (None, 270, 270, 1)       261381
# =================================================================
# Total params: 515,173
# Trainable params: 514,339
# Non-trainable params: 834
# _________________________________________________________________

# %%
with tf.device('/device:GPU:0'):
  vae.compile(optimizer=Adam(learning_rate=0.0001), loss=vae_loss)

# %% [markdown]
# # **Training**

# %%
now= datetime.now()
date_time = now.strftime("%Y%m%d%H%M")
cpFileName = 'VAE1'

es_cb = EarlyStopping(monitor='val_loss', patience=50, verbose=1, mode='auto')
chkpt = os.path.join(config['saveDir'], cpFileName + '-' + date_time + '-{epoch:02d}-{loss:.2f}-{val_loss:.2f}.hdf5')
cp_cb = ModelCheckpoint(filepath=chkpt, monitor='val_loss', verbose=1, save_best_only=False, mode='auto')
cpb_cb = ModelCheckpoint(filepath=os.path.join(config['saveDir'], cpFileName + '-' + date_time + '-best.hdf5'),
                         monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

# %%
# Load pretrained weights
wt_path = '/content/drive/MyDrive/UpWork/ChepVAE/10230/model_1/VAE1-202109181350-best.hdf5'
vae.load_weights(wt_path)

# %%
with tf.device('/device:GPU:0'):
  history = vae.fit(cdg_train, epochs=config['numEpochs'], validation_data=cdg_val, callbacks=[cp_cb, cpb_cb], 
                    verbose=1, workers=1, use_multiprocessing=False)

history_path = os.path.join(config["saveDir"], cpFileName + '-' + date_time + "-History.json")
print("Saving History at: {}".format(history_path))
json.dump(history.history, open(history_path, 'w'))
# Out:
# Epoch 1/5
# 3025/3025 [==============================] - ETA: 0s - batch: 1512.0000 - size: 32.0000 - loss: 8.5100
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# Epoch 00001: saving model to /content/drive/MyDrive/UpWork/ChepVAE/10230/model_2/VAE1-202109251436-01-8.51-12.71.hdf5
#
# Epoch 00001: val_loss improved from inf to 12.71247, saving model to /content/drive/MyDrive/UpWork/ChepVAE/10230/model_2/VAE1-202109251436-best.hdf5
# 3025/3025 [==============================] - 621s 204ms/step - batch: 1512.0000 - size: 32.0000 - loss: 8.5100 - val_loss: 12.7125
# Epoch 2/5
# 3025/3025 [==============================] - ETA: 0s - batch: 1512.0000 - size: 32.0000 - loss: 8.4919
# Epoch 00002: saving model to /content/drive/MyDrive/UpWork/ChepVAE/10230/model_2/VAE1-202109251436-02-8.49-12.87.hdf5
#
# Epoch 00002: val_loss did not improve from 12.71247
# 3025/3025 [==============================] - 617s 204ms/step - batch: 1512.0000 - size: 32.0000 - loss: 8.4919 - val_loss: 12.8714
# Epoch 3/5
# 3025/3025 [==============================] - ETA: 0s - batch: 1512.0000 - size: 32.0000 - loss: 8.4851
# Epoch 00003: saving model to /content/drive/MyDrive/UpWork/ChepVAE/10230/model_2/VAE1-202109251436-03-8.49-12.93.hdf5
#
# Epoch 00003: val_loss did not improve from 12.71247
# 3025/3025 [==============================] - 617s 204ms/step - batch: 1512.0000 - size: 32.0000 - loss: 8.4851 - val_loss: 12.9302
# Epoch 4/5
# 3025/3025 [==============================] - ETA: 0s - batch: 1512.0000 - size: 32.0000 - loss: 8.4788
# Epoch 00004: saving model to /content/drive/MyDrive/UpWork/ChepVAE/10230/model_2/VAE1-202109251436-04-8.48-12.83.hdf5
#
# Epoch 00004: val_loss did not improve from 12.71247
# 3025/3025 [==============================] - 617s 204ms/step - batch: 1512.0000 - size: 32.0000 - loss: 8.4788 - val_loss: 12.8261
# Epoch 5/5
# 3025/3025 [==============================] - ETA: 0s - batch: 1512.0000 - size: 32.0000 - loss: 8.4757
# Epoch 00005: saving model to /content/drive/MyDrive/UpWork/ChepVAE/10230/model_2/VAE1-202109251436-05-8.48-12.87.hdf5
#
# Epoch 00005: val_loss did not improve from 12.71247
# 3025/3025 [==============================] - 616s 204ms/step - batch: 1512.0000 - size: 32.0000 - loss: 8.4757 - val_loss: 12.8678
# Saving History at: /content/drive/MyDrive/UpWork/ChepVAE/10230/model_2/VAE1-202109251436-History.json

# %%
def plotTraining(history_path, start_epoch=0):
    with open(history_path) as f:
        history = json.load(f)

    loss = history['loss'][start_epoch:]
    val_loss = history['val_loss'][start_epoch:]
    epochs = range(1, len(loss) + 1)

    plt.figure()
    plt.plot(epochs, loss, 'g-')
    plt.plot(epochs, val_loss, 'r-')
    plt.title('Training and validation loss')
    plt.gca().legend(('Training', 'Validation'))
    axes = plt.gca()
    bottom, top = axes.get_ylim()
    plt.show()

# %%
plotTraining('/content/drive/MyDrive/UpWork/ChepVAE/10230/model_2/VAE1-202109251436-History.json', 1)

# %% [markdown]
# # Validation - Reconstruction Error

# %%
wt_path = 'VAE1-202109251436-best.hdf5'
vae.load_weights(os.path.join(config['saveDir'], wt_path))

# %%
mse_value = 0.0
for idx in tqdm(range(len(cdg_val))):
  xx = cdg_val.__getitem__(idx)
  prediction = vae.predict(xx[0])
  error2 = (xx[0] - prediction)**2
  mse_value += np.mean(error2)
mse_value = mse_value / len(cdg_val)
mse_value
# Out:
#   0%|          | 0/709 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 100%|██████████| 709/709 [01:29<00:00,  7.91it/s]
# 0.0001743951601568463

# %% [markdown]
# # Prediction

# %%
# data_path = '/content/drive/MyDrive/UpWork/ChepVAE/Data/hdf5/'
output_path = 'prediction_rotation.csv'
col_names = ['vec_' + str(i) for i in range(config['latentDim'])]

wt_path = 'VAE1-202109251436-best.hdf5'
vae.load_weights(os.path.join(config['saveDir'], wt_path))

# %%
# Remove prediction file, if already exist
if os.path.exists(output_path):
  os.remove(output_path)

pbar = tqdm(sorted(os.listdir(data_path)))
for file_name in pbar:
  pbar.set_description("Processing: {}".format(file_name))
  hdf5_path = os.path.join(data_path, file_name)
  data = h5py.File(hdf5_path, 'r')
  df = pd.DataFrame({'Filename':file_name, 'index':range(len(data['data']))})
  prediction = encoder.predict(np.expand_dims(data['data'], axis=3))
  df[col_names] = prediction[2]
  with open(output_path, 'a') as f:
    df.to_csv(f, mode='a', header=f.tell()==0, index=False)
# Out:
# Processing: FoilHole_14817225_Data_14817538_14817539_20170415_1339-2619_cor2_DW.h5:   0%|          | 0/296 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# Processing: FoilHole_14819468_Data_14817538_14817539_20170416_1146-3186_cor2_DW.h5: 100%|██████████| 296/296 [09:08<00:00,  1.85s/it]

# %%
# !cp prediction_rotation.csv /content/drive/MyDrive/UpWork/ChepVAE/10230/prediction_rotation.csv
